# %%
from graph_tool.all import *
import pickle
import matplotlib
import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import random
import math
import collections
import csv
import timeit

def toc(start_time):
    elapsed = timeit.default_timer() - start_time
    print(elapsed)
start_time = timeit.default_timer()

#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
#matplotlib.rcParams.update({'font.size': 18})

# from all_functions import *
from statistics import *

from ADAM_model_power_law import *

from multiprocessing import Process
from joblib import Parallel, delayed


path_code='/mnt/sdb1/sandeep/1.Reciprocity/code/'
path_data='/mnt/sdb1/sandeep/1.Reciprocity/data/'
path_results='/mnt/sdb1/sandeep/1.Reciprocity/res/'

# %%
file_name

# %%
#----------------------------------------
# ADA
#----------------------------------------
str_neg='$ a_i \propto 1/b_i $'
str_pos='$ a_i \propto b_i$'
# str_neg='$a$'
# str_pos='$a_i ~ b_i$'

actual_num_trials=5;


ANTI_=0;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADAM_trials_'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
storeGamma=np.linspace(-4,-2,21)
x=storeGamma;
x =  [abs(ele) for ele in x]
fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'ro-');y=mean_b;axs[0, 1].plot(x, y,'ro-')
y=mean_c;axs[1, 0].plot(x, y,'ro-');y=mean_d;axs[1, 1].plot(x, y,'ro-',label='ADAM, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;
    
#-------------------------------------------

ANTI_=1;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADAM_trials_'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
x=storeGamma;
x =  [abs(ele) for ele in x]
# fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'r.-');y=mean_b;axs[0, 1].plot(x, y,'r.-')
y=mean_c;axs[1, 0].plot(x, y,'r.-');y=mean_d;axs[1, 1].plot(x, y,'r.-',label='ADAM, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;

#----------------------------------------
# ADA
#----------------------------------------


ANTI_=0;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADA_trials_anti'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
x=storeGamma;
x =  [abs(ele) for ele in x]
# fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'bo-');y=mean_b;axs[0, 1].plot(x, y,'bo-')
y=mean_c;axs[1, 0].plot(x, y,'bo-');y=mean_d;axs[1, 1].plot(x, y,'bo-',label='ADA, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;
    
#-------------------------------------------

ANTI_=1;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADA_trials_anti'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
x=storeGamma;
x =  [abs(ele) for ele in x]
# fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'b.-');y=mean_b;axs[0, 1].plot(x, y,'b.-')
y=mean_c;axs[1, 0].plot(x, y,'b.-');y=mean_d;axs[1, 1].plot(x, y,'b.-',label='ADA, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;

axs[1, 1].legend(loc='upper right',fontsize=8,bbox_to_anchor=(1.65, 2.5));
   
    

plt.savefig(path_results+'fig_3_model_trials_'+str(actual_num_trials)+'.pdf', bbox_inches = "tight")

# %%
#----------------------------------------
# ADA
#----------------------------------------
str_neg='$ a_i \propto 1/b_i $'
str_pos='$ a_i \propto b_i$'
# str_neg='$a$'
# str_pos='$a_i ~ b_i$'

actual_num_trials=10;


ANTI_=0;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADAM_trials_'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
storeGamma=np.linspace(-4,-2,21)
x=storeGamma;
x =  [abs(ele) for ele in x]
fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'ro-');y=mean_b;axs[0, 1].plot(x, y,'ro-')
y=mean_c;axs[1, 0].plot(x, y,'ro-');y=mean_d;axs[1, 1].plot(x, y,'ro-',label='ADAM, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;
    
#-------------------------------------------


#----------------------------------------
# ADA
#----------------------------------------


ANTI_=0;
if ANTI_==1:str_corr=str_neg; 
else: str_corr=str_pos;
file_name = path_results+'results_ADA_trials_anti'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();

l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
for xx in results:    
    a,b,c,d=xx;    cc=cc+1
    l_rec_vs_Gamma.append(a);E_rec_vs_Gamma.append(b);B_nodes_vs_Gamma.append(c);B_edges_vs_Gamma.append(d)
mean_a=np.mean(np.array(l_rec_vs_Gamma),0);mean_b=np.mean(np.array(E_rec_vs_Gamma),0);mean_c=np.mean(np.array(B_nodes_vs_Gamma),0);mean_d=np.mean(np.array(B_edges_vs_Gamma),0);
#PLOTTING behaviour as a function of number of Gamma
x=storeGamma;
x =  [abs(ele) for ele in x]
# fig, axs = plt.subplots(2, 2);fig.tight_layout(pad=3.0)
y=mean_a;axs[0, 0].plot(x, y,'bo-');y=mean_b;axs[0, 1].plot(x, y,'bo-')
y=mean_c;axs[1, 0].plot(x, y,'bo-');y=mean_d;axs[1, 1].plot(x, y,'bo-',label='ADA, ' +(str_corr))
i=0;labels_=['P(l_{rec})','P(E_{rec})','B_{nodes}','B_{edges}'];fig.suptitle('Nodes, N=500; Edges, E=5000')
for ax in axs.flat:    ax.set(xlabel='power-law exponent of activity, $\gamma$', ylabel='$'+labels_[i]+'$');i=i+1;
    

axs[1, 1].legend(loc='upper right',fontsize=8,bbox_to_anchor=(1.65, 2.5));
   
    

plt.savefig(path_results+'fig_3_model_trials_'+str(actual_num_trials)+'.pdf', bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6e417d6b7be2> in <module>
#      43 else: str_corr=str_pos;
#      44 file_name = path_results+'results_ADA_trials_anti'+str(ANTI_)+'_'+str(actual_num_trials)+'.pkl'
# ---> 45 open_file = open(file_name, "rb");results=pickle.load(open_file);open_file.close();
#      46
#      47 l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];cc=0
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/sdb1/sandeep/1.Reciprocity/res/results_ADA_trials_anti0_10.pkl'
