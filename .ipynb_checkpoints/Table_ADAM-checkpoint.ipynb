# %%
from graph_tool.all import *
import graph_tool as gt
import pickle
import matplotlib
import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

import sys
import matplotlib.pyplot as plt
import random
import math
import collections
import csv
import timeit
import time

def toc(start_time):
    elapsed = timeit.default_timer() - start_time
    print(elapsed)
start_time = timeit.default_timer()

#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
#matplotlib.rcParams.update({'font.size': 18})
from functions_reci_bursty import *
from statistics import *

# a more general path that works for all -sam
x_dir=os.getcwd().split('/');
x_dir=os.getcwd().replace(x_dir[len(x_dir)-1],'')
# os.chdir(x_dir+'data/data_raw')

path_code='/mnt/sdb1/sandeep/1.Reciprocity/codes/'
path_data=x_dir+'data/data_raw/'
path_results='/mnt/sdb1/sandeep/1.Reciprocity/res/'

# %%
from ADAM_with_parameters_from_empirical import *

df_edges_email = pd.read_table(
    path_data+'email-Eu-core-temporal.txt',header=None,sep=" ")
df_edges_email.columns = ['from', 'to', 't_second']
# print(df_edges_email)

df_edges_college = pd.read_table(    path_data+'CollegeMsg.txt',header=None,sep=" ")
df_edges_college.columns = ['from', 'to', 't_second']
# print(df_edges_email)


counter_no_reply = 0
counter_event = 0
data = []

import csv
with open(path_data+'calls.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for line in list(spamreader)[1:]:
        counter_event+=1
        if int(line[0].split(',')[-1]) == -1 :
            counter_no_reply += 1
        else:
            L = np.asarray(line[0].split(',')).astype(int)[:-1]
            data.append([L[1],L[2],L[0]])
            
print('counter_no_reply',counter_no_reply)
print('counter_event',counter_event)
print('Proportion of calls with no reply',round(counter_no_reply/counter_event,3))

df_edges_calls = pd.DataFrame(data, columns = ['from', 'to', 't_second'])
df_edges_calls=df_edges_calls.drop_duplicates();

with open(path_data+'sms_ijt.pickle', 'rb') as handle:
    data = pickle.load(handle)
df_edges_sms = pd.DataFrame(data, columns = ['from', 'to', 't_second'])
# Out:
# counter_no_reply 366
# counter_event 3600
# Proportion of calls with no reply 0.102

# %% [markdown]
# ### 1.1-twitter data

# %% [raw]
# edges = pd.concat([mentions_edges, replay_edges, retweets_edges])
# edges['created_at'] = pd.to_datetime(edges['created_at'])

# %%
df_edges_mentions= pd.read_pickle(path_data+'/df_edges_mentions.pkl')
df_edges_retw= pd.read_pickle(path_data+'/df_edges_retw.pkl')
df_edges_reply= pd.read_pickle(path_data+'./df_edges_reply.pkl')


df_edges_reply=df_edges_reply.drop_duplicates();
df_edges_retw=df_edges_retw.drop_duplicates();
df_edges_mentions=df_edges_mentions.drop_duplicates();

# %%
df_edges_reply.columns=['from','to','t_second']
df_edges_retw.columns=['from','to','t_second']
df_edges_mentions.columns=['from','to','t_second']

# %%
def fix_twitter(x):
    if isinstance(x,int):
        return x
    elif '_assigned' in x:
        return int(x.split('_')[0])
    else:
        return int(x)
    
# list of all data sets
list_datasets = [df_edges_mentions,df_edges_retw,df_edges_reply]
    
df_edges_retw['to']=df_edges_retw['to'].apply(fix_twitter)
df_edges_retw['from']=df_edges_retw['from'].apply(fix_twitter)

    
df_edges_mentions['to']=df_edges_mentions['to'].apply(fix_twitter)
df_edges_mentions['from']=df_edges_mentions['from'].apply(fix_twitter)

    
df_edges_reply['to']=df_edges_reply['to'].apply(fix_twitter)
df_edges_reply['from']=df_edges_reply['from'].apply(fix_twitter)

# %%
# for key_ in dict_df_edges:
#     print(dict_df_edges[key_].head())

# %%
def call_to_ADAM(df_edges,alpha,beta):

    [g,g_D]=to_graph(df_edges,'from','to','t_second','t_minutes','t_hours','t_days')
    degree_dist_O = g_D.degree_property_map("out")
    degree_dist_I = g_D.degree_property_map("in")

    k_out=degree_dist_O.a
    k_in=degree_dist_I.a

    # THESE ARE ARE INPUTS WE MUST PROVIDE (FROM THE EMPIRICAL NETWORK)
    N=g.num_vertices()
    E=g.num_edges()

    # CALL TO ACVITY DRIVEN MODEL, RETURN TIME ORDERED EDGELIST
    elist,num_edges=create_ADAM_elist(N,E,k_in,k_out,alpha,beta)


    df_edges_ADA_MODEL=pd.DataFrame(list(elist))
    df_edges_ADA_MODEL.columns = ['from', 'to', 't_second']

    return df_edges_ADA_MODEL

def call_ADAM_and_AVG_measures(df_edges,trials,alpha,beta,key_,method_,n_thresh):

    l_rec=[];E_rec=[];B_nodes=[];B_edges=[];
    for i in range(trials):
        print(i,end="\r")
        df_edges_ADAM_MODEL=call_to_ADAM(df_edges,alpha,beta)
        Y=measures(df_edges_ADAM_MODEL,'ADAM MODEL',n_thresh)
#         print(Y.iloc[0,0])
        E_rec.append(Y.iloc[0,0])
        l_rec.append(Y.iloc[0,1])
        B_nodes.append(Y.iloc[0,2])
        B_edges.append(Y.iloc[0,3])
    results = {}
    results['Method'] = key_+method_
#     results['P(l_rec)'] = str(round(mean(l_rec),4)) + u"\u00B1" +str(round(variance(l_rec)**(.5),4))
#     results['P(E_rec)'] = str(round(mean(E_rec),4)) + u"\u00B1" +str(round(variance(E_rec)**(.5),4))
#     results['B_nodes'] =str(round(mean(B_nodes),4)) + u"\u00B1" +str(round(variance(B_nodes)**(.5),4))
#     results['B_edges'] = str(round(mean(B_edges),4)) + u"\u00B1" +str(round(variance(B_edges)**(.5),4))
    results['P(E_rec)'] = mean(E_rec)
    results['P(l_rec)'] = mean(l_rec)
    results['B_nodes'] = mean(B_nodes)
    results['B_edges'] = mean(B_edges)

    results_std = {}
    results_std['Method'] = key_+method_
    results_std['P(E_rec)'] = np.power(np.nanvar(np.array(E_rec)),.5)
    results_std['P(l_rec)'] = np.power(np.nanvar(np.array(l_rec)),.5)
    results_std['B_nodes'] = np.power(np.nanvar(np.array(B_nodes)),.5)
    results_std['B_edges'] = np.power(np.nanvar(np.array(B_edges)),.5)
    

    results_df = pd.DataFrame.from_records([results])
    results_df.set_index("Method", inplace = True)
    results_df_std = pd.DataFrame.from_records([results_std])
    results_df_std.set_index("Method", inplace = True)
    return results_df,results_df_std

# %%
print(df_edges_calls.shape[0],df_edges_sms.shape[0],df_edges_college.shape[0],df_edges_email.shape[0],df_edges_retw.shape[0],df_edges_mentions.shape[0])
# Out:
# 3234 24333 59835 332334 498145 693724

# %%
CHOICE_OF_OBJECTIVE=2

# %%
dict_res=dict()
dict_res_std=dict()
dict_para1para2=dict()
t_ic=time.time()


for events_considered in [10000,15000,20000,25000,30000]:
# for events_considered in [10000]:
        # dict_df_edges={'calls':df_edges_calls, 'sms':df_edges_sms,'college':df_edges_college,'email':df_edges_email}
    dict_df_edges={'calls':df_edges_calls.iloc[0:min(events_considered,df_edges_calls.shape[0]):],\
                       'sms':df_edges_sms.iloc[0:min(events_considered,df_edges_sms.shape[0]):],\
                       'college':df_edges_college.iloc[0:min(events_considered,df_edges_college.shape[0]):],\
                       'email':df_edges_email.iloc[0:min(events_considered,df_edges_email.shape[0]):],\
                      'retweets':df_edges_retw.iloc[0:min(events_considered,df_edges_retw.shape[0]):],\
                       'mentions':df_edges_mentions.iloc[0:min(events_considered,df_edges_mentions.shape[0]):]}
    for key_ in dict_df_edges:
        df_edges=dict_df_edges[key_]
        print(key_,df_edges.shape)
        
        # updated ADAM (memory fit)
        # finiding memory variables 
        df_ck,leg_,xtick_s,bin_s=compute_df_ck(df_edges)

        if CHOICE_OF_OBJECTIVE==1:
            popt1=plot_pk_vs_n_SINGLE(df_ck,bin_s,CHOICE_OF_OBJECTIVE);
            alpha,beta=popt1
        else:
            popt2=plot_pk_vs_n_SINGLE(df_ck,bin_s,CHOICE_OF_OBJECTIVE);
            alpha=popt2[0]
            beta=0

        print(key_,'------alpha,beta=',alpha,beta)

#----------------------------------------------
# filter on edges:  throsholding using n_events
#----------------------------------------------
# n_thresh=5
#----------------------------------------------

        for n_thresh in [3]:



            t_oc=time.time()
            print('events_considered, n_thresh, dataset--',events_considered,', ',n_thresh,', ',key_)
            with open("/mnt/sdb1/sandeep/1.Reciprocity/codes/0.z_prog_table_ADAM.txt", "a") as file_object:
                file_object.write('dataset starting='+'events_considered, n_thresh, dataset--'+str(events_considered)+', '+str(n_thresh)+', '+str(key_)+'----'+str(round(t_oc-t_ic,2))+'\n')


            dict_para1para2[key_]=[alpha,beta]

            # Calling function that calls ADAM 

            measures_original=measures(df_edges,key_+', Original',n_thresh)
        #     print('\n',measures_original)
            trials=5
            method_=', ADAM'
            results_df1,results_df1_std=call_ADAM_and_AVG_measures(df_edges,trials,alpha,beta,key_,method_,n_thresh)
            measures_original=measures_original.append(results_df1)

            alpha_ADA=1
            beta_ADA=1
            method_=', ADA'
            results_df2,results_df2_std=call_ADAM_and_AVG_measures(df_edges,trials,alpha_ADA,beta_ADA,key_,method_,n_thresh)
            measures_original=measures_original.append(results_df2)
            dict_res[key_]=measures_original
            dict_res_std[key_]=results_df1_std.append(results_df2_std)
            t_oc=time.time()
            with open("/mnt/sdb1/sandeep/1.Reciprocity/codes/0.a_prog_table_ADAM.txt", "a") as file_object:
                file_object.write('dataset FINISHED='+(key_)+'----'+str(round(t_oc-t_ic,2))+'\n')


    file_name = path_results+'b_dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
    '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
    open_file = open(file_name, "wb")
    pickle.dump(dict_res, open_file)
    open_file.close()

    file_name = path_results+'b_dict_error_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
    '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
    open_file = open(file_name, "wb")
    pickle.dump(dict_res_std, open_file)
    open_file.close()

# %%
def simpleaxis(ax,xlab_,ylab_):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    ax.set_xlabel(xlab_,fontsize=ff) 
    ax.set_ylabel(ylab_,fontsize=ff)        
    plt.tight_layout()

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})
# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 8, 'font.style': 'normal', 'font.family':'serif'})

ff=8

# %%
dict_res_err
dict_res
# Out:
# {'calls':                  P(E_rec)  P(l_rec)   B_nodes   B_edges
#  calls, Original  0.449979  0.894340  0.168528  0.093624
#  calls, ADAM      0.450332  0.858269 -0.148348 -0.202969
#  calls, ADA            NaN       NaN       NaN       NaN,
#  'sms':                P(E_rec)  P(l_rec)   B_nodes   B_edges
#  sms, Original  0.757349  0.996988  0.362951  0.292864
#  sms, ADAM      0.479820  0.966326 -0.170807 -0.199221
#  sms, ADA       0.445260  0.722294 -0.222396 -0.312898,
#  'college':                    P(E_rec)  P(l_rec)   B_nodes   B_edges
#  college, Original  0.563583  0.719899  0.211686 -0.058695
#  college, ADAM      0.335886  0.714336 -0.048854 -0.158133
#  college, ADA       0.308450  0.493326 -0.355921 -0.402110,
#  'email':                  P(E_rec)  P(l_rec)   B_nodes   B_edges
#  email, Original  0.467830  0.793413  0.142631 -0.000261
#  email, ADAM      0.398918  0.795596 -0.057849 -0.175090
#  email, ADA       0.431563  0.661661 -0.362794 -0.376989,
# ...

# %%
trials=5

fig, axs = plt.subplots(1, 2, figsize =(10, 2.5), sharey='col', sharex='col')
colors_=['black','indianred','blue']
it_n_thresh=-1
for n_thresh in [3]:
    it_n_thresh+=1
    for events_considered in [10000]:
        print(events_considered,', ',n_thresh)

        file_name = path_results+'b_dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
        file_name_err = path_results+'b_dict_error_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
        with open(file_name, 'rb') as f:
            dict_res= pickle.load(f)    
        with open(file_name_err, 'rb') as f:
            dict_res_err= pickle.load(f)    
            
        lin_style=['x','o','^']
        for col_selected in [0,1]:
            dataset_num=0
            for key_ in dict_res.keys():
                dataset_num+=1
                zz=list(dict_res[key_].iloc[:,col_selected])
                zz_err=list(dict_res_err[key_].iloc[:,col_selected])
                for x in range(len(zz)):
                    X=dataset_num+3*events_considered/10**5-1.2
                    if (dataset_num==6) and (events_considered==10000):
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                        axs[col_selected].plot(X,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                        if x>0:
                            axs[col_selected].errorbar(X, zz[x], zz_err[x-1]/trials^.5, mfc='w',mec='w', ms=0, mew=4,)

                    else:
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4)
                        axs[col_selected].plot(X,zz[x],lin_style[x],color=colors_[x],alpha=.4)
                        if x>0:
                            axs[col_selected].errorbar(X, zz[x], zz_err[x-1]/trials^.5, mfc='w',mec='w', ms=0, mew=4,)


#                 print(key_,dict_res[key_],'\n')
#             print('\n-------------------------------\n')
            axs[col_selected].set_xticks([0,1,2,3,4,5])
#             axs[it_n_thresh,col_selected].set_xticks([0,1,2,3,4,5])
            axs[col_selected].set_xticklabels(list(dict_res.keys()))
            axs[col_selected].set_title('$n_{events}^{threshold}=$'+str(n_thresh))

            ylab_=list(dict_res[key_].columns)[col_selected]
            simpleaxis(axs[col_selected],'',ylab_)
axs[col_selected].legend(bbox_to_anchor=(1.5, 1.05))
simpleaxis(axs[col_selected],'',ylab_)
# Out:
# 10000 ,  3

# %%
trials=5

fig, axs = plt.subplots(1, 2, figsize =(10, 2.5), sharey='col', sharex='col')
colors_=['black','indianred','blue']
it_n_thresh=-1
for n_thresh in [3]:
    it_n_thresh+=1
    for events_considered in [10000,15000,20000,25000,30000]:
        print(events_considered,', ',n_thresh)

        file_name = path_results+'a_dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
        file_name_err = path_results+'a_dict_error_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
        with open(file_name, 'rb') as f:
            dict_res= pickle.load(f)    
            
        lin_style=['x','o','^']
        for col_selected in [0,1]:
            dataset_num=0
            for key_ in dict_res.keys():
                dataset_num+=1
                zz=list(dict_res[key_].iloc[:,col_selected])
                for x in range(len(zz)):

                    if (dataset_num==6) and (events_considered==30000):
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                        axs[col_selected].plot(dataset_num+3*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                    else:
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4)
                        axs[col_selected].plot(dataset_num+3*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4)

#                 print(key_,dict_res[key_],'\n')
#             print('\n-------------------------------\n')
            axs[col_selected].set_xticks([0,1,2,3,4,5])
#             axs[it_n_thresh,col_selected].set_xticks([0,1,2,3,4,5])
            axs[col_selected].set_xticklabels(list(dict_res.keys()))
            axs[col_selected].set_title('$n_{events}^{threshold}=$'+str(n_thresh))

            ylab_=list(dict_res[key_].columns)[col_selected]
            simpleaxis(axs[col_selected],'',ylab_)
axs[col_selected].legend(bbox_to_anchor=(1.5, 1.05))
simpleaxis(axs[col_selected],'',ylab_)
# Out:
# 10000 ,  3
# 15000 ,  3
# 20000 ,  3
# 25000 ,  3
# 30000 ,  3

# %% [markdown]
# ## add ERROR BARS

# %% [markdown]
# ### events_considered/10**5

# %%
trials=5

fig, axs = plt.subplots(1, 2, figsize =(10, 3.5), sharey='col', sharex='col')
colors_=['black','indianred','blue']
it_n_thresh=-1
for n_thresh in [3]:
    it_n_thresh+=1
    for events_considered in [10000,20000,30000]:
        print(events_considered,', ',n_thresh)

        file_name = path_results+'dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'.pkl'
        with open(file_name, 'rb') as f:
            dict_res= pickle.load(f)    
            
        lin_style=['x','o','^']
        for col_selected in [0,1]:
            dataset_num=0
            for key_ in dict_res.keys():
                dataset_num+=1
                zz=list(dict_res[key_].iloc[:,col_selected])
                for x in range(len(zz)):

                    if (dataset_num==6) and (events_considered==30000):
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                        axs[col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4,label=list(dict_res[key_].index)[x].split(',')[1])
                    else:
#                         axs[it_n_thresh,col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4)
                        axs[col_selected].plot(dataset_num+2*events_considered/10**5-1.2,zz[x],lin_style[x],color=colors_[x],alpha=.4)

#                 print(key_,dict_res[key_],'\n')
#             print('\n-------------------------------\n')
            axs[col_selected].set_xticks([0,1,2,3,4,5])
#             axs[it_n_thresh,col_selected].set_xticks([0,1,2,3,4,5])
            axs[col_selected].set_xticklabels(list(dict_res.keys()))
            axs[col_selected].set_title('$n_{events}^{threshold}=$'+str(n_thresh))

            ylab_=list(dict_res[key_].columns)[col_selected]
            simpleaxis(axs[col_selected],'',ylab_)
axs[col_selected].legend(bbox_to_anchor=(1.5, 1.05))
simpleaxis(axs[col_selected],'',ylab_)
# Out:
# 10000 ,  3
# 20000 ,  3
# 30000 ,  3

# %%
trials=5

for events_considered in [10000,20000,30000]:
    for n_thresh in [5]:
        print(events_considered,', ',n_thresh)

        file_name = path_results+'dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
        '_n_threshold_'+str(n_thresh)+'.pkl'

#         file_name = path_results+'a_dict_empirical_vs_model_trials_'+str(trials)+'_events_considered_'+str(events_considered)+\
#             '_n_threshold_'+str(n_thresh)+'_objective_'+str(CHOICE_OF_OBJECTIVE)+'.pkl'
        with open(file_name, 'rb') as f:
            dict_res= pickle.load(f)    
            for key_ in dict_res.keys():
                print(key_,dict_res[key_],'\n')
            print('\n-------------------------------\n')
# Out:
# 10000 ,  5
# calls                  P(E_rec)  P(l_rec)   B_nodes   B_edges
# calls, Original  0.440576  0.950276  0.206457  0.180625
# calls, ADAM      0.404051  0.876467 -0.126553 -0.136790
# calls, ADA            NaN       NaN       NaN       NaN
#
# sms                P(E_rec)  P(l_rec)   B_nodes   B_edges
# sms, Original  0.745338  1.000000  0.422909  0.369614
# sms, ADAM      0.437020  0.971536 -0.071834 -0.102567
# sms, ADA            NaN       NaN       NaN       NaN
#
# college                    P(E_rec)  P(l_rec)   B_nodes   B_edges
# college, Original  0.552337  0.746377  0.294711  0.097612
# college, ADAM      0.349301  0.766713 -0.055382 -0.102045
# college, ADA            NaN       NaN       NaN       NaN
#
# email                  P(E_rec)  P(l_rec)   B_nodes   B_edges
# email, Original  0.423613  0.832155  0.175513  0.132087
# email, ADAM      0.407793  0.874673 -0.045999 -0.096211
# email, ADA            NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ## Visualizing ADAM network at $\alpha$=1,2,3,4

# %%
np.linspace(-4.1,-1.1,4)
# Out:
# array([-4.1, -3.1, -2.1, -1.1])

# %%
from all_functions import *
from statistics import *

from ADAM_model_power_law import *


N=500      # number of nodes in the empirical network 
epsi=10**-3 # minimum allowed node activity
E=5000;
storeGamma=np.linspace(-4.1,-1.1,4)
Gamma=1.1
l_rec_vs_Gamma=[];E_rec_vs_Gamma=[];B_nodes_vs_Gamma=[];B_edges_vs_Gamma=[];

para1=1;para2=0;

# for Gamma in storeGamma:
g=Gamma+1
print('Gamma=',Gamma,)

elist,num_events=create_ADAM_power_law_elist(N,E,epsi,g,para1,para2)
# Y=measures(elist,'ADAM MODEL')

W_mat=np.zeros([N,N]);
for edge_ in elist:
    source_=edge_[0]
    target_=edge_[1]
    W_mat[source_,target_]=W_mat[source_,target_]+1
    
fig = plt.figure(figsize=(8, 8));    

ax_ = fig.add_subplot(1, 1, 1);

plot_w_networks(fig,W_mat)    

# bv, be = betweenness(g)
# be.a /= be.a.max() / 5
# graph_draw(g, pos=pos, vertex_fill_color=bv, edge_pen_width=be,
#            output="filtered-bt.svg"
# Out:
# Gamma= 1.1
# 0.9464

# %%
elist_agg=[]
c_edges=0
for i in range(N):
    for j in range(N):
        w=W_mat[i,j];
        if w>0:
            elist_agg.append([i,j,w])
            c_edges=c_edges+1
elist_agg
G = Graph(directed=True);
G.ep["weight"] = G.new_edge_property("int");
eprops = [G.ep["weight"]];
G.add_edge_list(elist_agg, eprops=eprops);
G.num_vertices();
G.num_edges();
# for w in G.ep["weight"]:
#     print(w)
fig = plt.figure(figsize=(8, 8));    
ax_ = fig.add_subplot(1, 1, 1);
gt.draw.fruchterman_reingold_layout(G, weight=G.ep["weight"]);

g = lattice([10, 10])
# gt.draw(g)
gt.draw.fruchterman_reingold_layout(g);

# %%
def plot_w_networks(fig,W_mat):


    ##___________________________________________________
    import networkx as nx
    G = nx.Graph()
    G=nx.from_numpy_matrix(abs(W_mat))
    node_list=np.arange(0,10)
    #________________________

    labels = nx.get_edge_attributes(G,'weight')
    all_weights=[]
    for (node1,node2,data) in G.edges(data=True):
        all_weights.append(data['weight']) #we'll use this when determining edge thickness
    unique_weights = list(set(all_weights))
#     if i_country==0:
    pos = nx.spring_layout(G)
    for weight in unique_weights:
        weighted_edges = [(node1,node2) for (node1,node2,edge_attr) in G.edges(data=True) if edge_attr['weight']==weight]
        width =.1*weight
#         width = 10*weight*len(node_list)/sum(all_weights)
        nx.draw_networkx_edges(G,pos,edgelist=weighted_edges,width=width,ax=ax_)
#     axes = plt.gca()
    y_min, y_max = ax_.get_ylim()
    x_min, x_max = ax_.get_ylim()


#     ax_.set_ylim
    aa=1;ax_.set_ylim([ -aa*y_max,aa* y_max])
    ax_.set_xlim([-aa*x_max,aa* x_max])
#     ax_.set_title(countries30[i_country])
    ax_.axis('off')
